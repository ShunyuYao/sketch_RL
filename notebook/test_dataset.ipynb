# %%
import sys
import pandas as pd
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from PIL import Image
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sys.path.append('../')

# %%
from util.base_dataset import FaceEdgeFolder

# %%
df = pd.read_csv('../dataset/emotion_id.csv')

# %%
dataset = FaceEdgeFolder('../dataset/face_landmark/all_imgs_canny/all_edges_img/', df,
                        transform=transforms.Compose((transforms.Resize((384, 256)),
                                                     transforms.ToTensor())) )

# %%
dataloader = DataLoader(dataset, batch_size=4,
                       shuffle=True, num_workers=4)

# %%
bs = next(iter(dataloader))

# %%
bs['first_img'].size()
# Out:
# torch.Size([4, 1, 1, 384, 256])

# %%
bs['succeed_imgs'].size()
# Out:
# torch.Size([4, 1, 5, 384, 256])

# %%
dataset[0]['first_img'].size()
# Out:
# torch.Size([1, 1, 384, 256])

# %%
output_tensor = dataset[0]['succeed_imgs']

# %%
dataset.selected_interv
# Out:
# 1

# %%
Image.fromarray((output_tensor[0,0]*255).detach().cpu().numpy().astype('uint8'), 'L')
# Out:
# <PIL.Image.Image image mode=L size=256x384 at 0x7F074A9FAE80>

# %%
Image.fromarray((output_tensor[0,1]*255).detach().cpu().numpy().astype('uint8'), 'L')
# Out:
# <PIL.Image.Image image mode=L size=256x384 at 0x7F074A9FAF28>

# %%
Image.fromarray((output_tensor[0,2]*255).detach().cpu().numpy().astype('uint8'), 'L')
# Out:
# <PIL.Image.Image image mode=L size=256x384 at 0x7F074A9FAF60>
